# %%
import pandas as pd
import numpy as np

weather = pd.read_csv('/Users/zaid/Downloads/weather.csv')
weather
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
weather.shape
# Out:
# (16743, 14)

# %%
weather.head()
# Out:
#    Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                0.00  2016-01-03           1             3       2016
# 1                0.00  2016-01-03           1             3       2016
# 2                0.16  2016-01-03           1             3       2016
# 3                0.00  2016-01-03           1             3       2016
# 4                0.01  2016-01-03           1             3       2016
#
#   Station.City Station.Code Station.Location Station.State  \
# 0   Birmingham          BHM   Birmingham, AL       Alabama
# 1   Huntsville          HSV   Huntsville, AL       Alabama
# 2       Mobile          MOB       Mobile, AL       Alabama
# 3   Montgomery          MGM   Montgomery, AL       Alabama
# 4    Anchorage          ANC    Anchorage, AK        Alaska
#
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 0                         39                         46
# 1                         39                         47
# ...

# %%
weather.tail()
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# 16738       Casper          CPR       Casper, WY       Wyoming
# 16739     Cheyenne          CYS     Cheyenne, WY       Wyoming
# 16740       Lander          LND       Lander, WY       Wyoming
# 16741      Rawlins          RWL      Rawlins, WY       Wyoming
# 16742     Sheridan          SHR     Sheridan, WY       Wyoming
#
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp  \
# 16738                         23                         32
# ...

# %% [markdown]
# weather.columns

# %%
weather.columns
# Out:
# Index(['Data.Precipitation', 'Date.Full', 'Date.Month', 'Date.Week of',
#        'Date.Year', 'Station.City', 'Station.Code', 'Station.Location',
#        'Station.State', 'Data.Temperature.Avg Temp',
#        'Data.Temperature.Max Temp', 'Data.Temperature.Min Temp',
#        'Data.Wind.Direction', 'Data.Wind.Speed'],
#       dtype='object')

# %%
weather.corr()
# Out:
#                            Data.Precipitation  Date.Month  Date.Week of  \
# Data.Precipitation                   1.000000    0.004692      0.076017
# Date.Month                           0.004692    1.000000      0.014674
# Date.Week of                         0.076017    0.014674      1.000000
# Date.Year                           -0.018465   -0.212646     -0.228081
# Data.Temperature.Avg Temp            0.121750    0.223009      0.048927
# Data.Temperature.Max Temp            0.069360    0.214630      0.057612
# Data.Temperature.Min Temp            0.172367    0.222454      0.037929
# Data.Wind.Direction                 -0.112015   -0.085088     -0.014450
# Data.Wind.Speed                     -0.003102   -0.116213     -0.019832
#
#                            Date.Year  Data.Temperature.Avg Temp  \
# Data.Precipitation         -0.018465                   0.121750
# Date.Month                 -0.212646                   0.223009
# ...

# %%
weather.isnull().sum()
# Out:
# Data.Precipitation           0
# Date.Full                    0
# Date.Month                   0
# Date.Week of                 0
# Date.Year                    0
# Station.City                 0
# Station.Code                 0
# Station.Location             0
# Station.State                0
# Data.Temperature.Avg Temp    0
# Data.Temperature.Max Temp    0
# Data.Temperature.Min Temp    0
# Data.Wind.Direction          0
# Data.Wind.Speed              0
# dtype: int64

# %%
weather.isnull().sum()/weather.shape[0]
# Out:
# Data.Precipitation           0.0
# Date.Full                    0.0
# Date.Month                   0.0
# Date.Week of                 0.0
# Date.Year                    0.0
# Station.City                 0.0
# Station.Code                 0.0
# Station.Location             0.0
# Station.State                0.0
# Data.Temperature.Avg Temp    0.0
# Data.Temperature.Max Temp    0.0
# Data.Temperature.Min Temp    0.0
# Data.Wind.Direction          0.0
# Data.Wind.Speed              0.0
# dtype: float64

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#        data.precipitation   date.full  date.month  date.week of  date.year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       station.city station.code station.location station.state  \
# ...

# %%
weather.dtypes
# Out:
# data.precipitation           float64
# date.full                     object
# date.month                     int64
# date.week of                   int64
# date.year                      int64
# station.city                  object
# station.code                  object
# station.location              object
# station.state                 object
# data.temperature.avg temp      int64
# data.temperature.max temp      int64
# data.temperature.min temp      int64
# data.wind.direction            int64
# data.wind.speed              float64
# dtype: object

# %%
weather.index
# Out:
# RangeIndex(start=0, stop=16743, step=1)

# %%
weather.index.value_counts().sort_index()
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 16738    1
# 16739    1
# 16740    1
# 16741    1
# 16742    1
# Length: 16743, dtype: int64

# %%
weather["data.temperature.avg temp"].plot()
# Out:
# <AxesSubplot:>

# %%
weather["date.week of"].plot()
# Out:
# <AxesSubplot:>

# %%
#machine learning parts starts from here

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["station.city" , "station.code" , "station.state" , "date.month" , "date.week of" , "date.year"])]

# %%
predictors
# Out:
# Index(['data.precipitation', 'date.full', 'station.location',
#        'data.temperature.avg temp', 'data.temperature.max temp',
#        'data.temperature.min temp', 'data.wind.direction', 'data.wind.speed'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corrmap = df.corr()

figure = plt.figure(figsize = (10,10))

sns.heatmap(corrmap , vmax = 1 , square = True , annot = True , vmin = -1)
plt.show()

# %%
df.hist(figsize = (16,16))
plt.show()
